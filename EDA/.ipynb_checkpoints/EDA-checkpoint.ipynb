# %% [markdown]
# In this project, we will analyze human resources data by performing data wrangling & EDA.
#
# We will learn how to:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # CODING TASK #1. IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %% [markdown]
# ## Feature Information
#
# **Age:** Çalışanların yaş bilgisi (int64).
#
# **MonthlyIncome:** Aylık gelir bilgisi (float64).
#
# **Attrition:** İşten ayrılma durumu (object).
#
# **BusinessTravel:** İş seyahati sıklığı (object).
#
# **DailyRate:** Günlük ücret bilgisi (int64).
#
# **Department:** Çalışanların departman bilgisi (object).
#
# **DistanceFromHome:** Ev ile işyeri arasındaki mesafe (int64).
#
# **Education:** Eğitim seviyesi (int64).
#
# **EducationField:** Eğitim alanı (object).
#
# **EmployeeCount:** Çalışan sayısı (int64).
#
# **EmployeeNumber:** Çalışan numarası (float64).
#
# **EnvironmentSatisfaction:** Çalışma ortamı memnuniyeti (int64).
#
# **Gender:** Cinsiyet bilgisi (object).
#
# **HourlyRate:** Saatlik ücret bilgisi (int64).
#
# **JobInvolvement:** İşe katılım düzeyi (int64).
#
# **JobLevel:** İş seviyesi (int64).
#
# **JobRole:** İş rolü (object).
#
# **JobSatisfaction:** İş tatmini düzeyi (int64).
#
# **MaritalStatus:** Medeni durum (object).
#
# **MonthlyRate:** Aylık ücret bilgisi (float64).
#
# **NumCompaniesWorked:** Çalışılan şirket sayısı (int64).
#
# **Over18:** 18 yaşından büyük olma durumu (object).
#
# **OverTime:** Mesai durumu (object).
#
# **PercentSalaryHike:** Maaş artış yüzdesi (float64).
#
# **PerformanceRating:** Performans değerlendirme puanı (float64).
#
# **RelationshipSatisfaction:** İlişki memnuniyeti (int64).
#
# **StandardHours:** Standart çalışma saatleri (int64).
#
# **StockOptionLevel:** Hisse senedi opsiyon seviyesi (int64).
#
# **TotalWorkingYears:** Toplam çalışma yılı (int64).
#
# **TrainingTimesLastYear:** Geçen yıl yapılan eğitim sayısı (int64).
#
# **WorkLifeBalance:** İş-yaşam dengesi (int64).
#
# **YearsAtCompany:** Şirkette çalışma süresi (int64).
#
# **YearsInCurrentRole:** Mevcut pozisyonda çalışma süresi (int64).
#
# **YearsSinceLastPromotion:** Son terfiden bu yana geçen süre (int64).
#
# **YearsWithCurrManager:** Mevcut yöneticinin yanında çalışma süresi (int64).

# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Human_Resources.csv")
df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
df.tail()
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [5 rows x 35 columns]

# %%
df.sample(5)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1004   26         3578.0        No      Travel_Rarely        652
# 1181   49        13966.0        No      Travel_Rarely        465
# 1131   34         5063.0        No  Travel_Frequently        653
# 858    53        18606.0        No      Travel_Rarely       1223
# 1432   37        13744.0        No      Travel_Rarely        161
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1004  Research & Development                 7          3             Other
# 1181  Research & Development                 6          1     Life Sciences
# 1131  Research & Development                10          4  Technical Degree
# 858   Research & Development                 7          2           Medical
# 1432  Research & Development                10          3     Life Sciences
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1004              1  ...                         4             80
# 1181              1  ...                         2             80
# 1131              1  ...                         2             80
# 858               1  ...                         2             80
# 1432              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1004                0                  8                      2
# 1181                1                 30                      3
# 1131                1                  8                      3
# 858                 1                 26                      6
# 1432                1                 16                      2
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1004                3              7                   7
# 1181                3             15                  11
# 1131                2              8                   2
# 858                 3              7                   7
# 1432                3             16                  11
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 1004                       0                     7
# 1181                       2                    12
# 1131                       7                     7
# 858                        4                     7
# 1432                       6                     8
#
# [5 rows x 35 columns]

# %%
# Force Pandas to display all rows and columns
'''
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print(df)
'''
# Out:
# "\npd.set_option('display.max_rows', None)\npd.set_option('display.max_columns', None)\nprint(df)\n"

# %%
# number of rows and columns
df.shape
# Out:
# (1470, 35)

# %%
# Information about dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
#  13  HourlyRate                1470 non-null   int64
#  14  JobInvolvement            1470 non-null   int64
#  15  JobLevel                  1470 non-null   int64
#  16  JobRole                   1469 non-null   object
#  17  JobSatisfaction           1470 non-null   int64
#  18  MaritalStatus             1469 non-null   object
#  19  MonthlyRate               1468 non-null   float64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   float64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(5), int64(21), object(9)
# memory usage: 402.1+ KB

# %%
# Let's create a more detailed table for our features

# Create an empty list to store the output data
output_data = []

for col in df.columns:
    
    # If the number of unique values in the column is less than or equal to 10
    if df.loc[:, col].nunique() <= 10:
        # Get the unique values in the column
        unique_values = df.loc[:, col].unique()
        # Append the column name, number of unique values, unique values, and data type to the output data
        output_data.append([col, df.loc[:, col].nunique(), unique_values, df.loc[:, col].dtype])
    else:
        # Otherwise, append only the column name, number of unique values, and data type to the output data
        output_data.append([col, df.loc[:, col].nunique(),"-", df.loc[:, col].dtype])

output_df = pd.DataFrame(output_data, columns=['Column Name', 'Number of Unique Values', ' Unique Values ', 'Data Type'])

output_df
# Out:
#                  Column Name  Number of Unique Values  \
# 0                        Age                       43
# 1              MonthlyIncome                     1346
# 2                  Attrition                        2
# 3             BusinessTravel                        3
# 4                  DailyRate                      886
# 5                 Department                        3
# 6           DistanceFromHome                       29
# 7                  Education                        5
# 8             EducationField                        6
# 9              EmployeeCount                        1
# 10            EmployeeNumber                     1469
# 11   EnvironmentSatisfaction                        4
# 12                    Gender                        2
# 13                HourlyRate                       71
# 14            JobInvolvement                        4
# 15                  JobLevel                        5
# 16                   JobRole                        9
# 17           JobSatisfaction                        4
# 18             MaritalStatus                        3
# 19               MonthlyRate                     1425
# 20        NumCompaniesWorked                       10
# 21                    Over18                        1
# 22                  OverTime                        2
# 23         PercentSalaryHike                       15
# 24         PerformanceRating                        2
# 25  RelationshipSatisfaction                        4
# 26             StandardHours                        1
# 27          StockOptionLevel                        4
# 28         TotalWorkingYears                       40
# 29     TrainingTimesLastYear                        7
# 30           WorkLifeBalance                        4
# 31            YearsAtCompany                       37
# 32        YearsInCurrentRole                       19
# 33   YearsSinceLastPromotion                       16
# 34      YearsWithCurrManager                       18
#
#                                        Unique Values  Data Type
# 0                                                   -     int64
# 1                                                   -   float64
# 2                                           [Yes, No]    object
# 3      [Travel_Rarely, Travel_Frequently, Non-Travel]    object
# 4                                                   -     int64
# 5   [Sales, Research & Development, nan, Human Res...    object
# 6                                                   -     int64
# 7                                     [2, 1, 4, 3, 5]     int64
# 8   [Life Sciences, Other, Medical, nan, Marketing...    object
# 9                                                 [1]     int64
# 10                                                  -   float64
# 11                                       [2, 3, 4, 1]     int64
# 12                                [Female, Male, nan]    object
# 13                                                  -     int64
# 14                                       [3, 2, 4, 1]     int64
# 15                                    [2, 1, 3, 4, 5]     int64
# 16  [Sales Executive, Research Scientist, Laborato...    object
# 17                                       [4, 2, 3, 1]     int64
# 18                   [Single, Married, Divorced, nan]    object
# 19                                                  -   float64
# 20                     [8, 1, 6, 9, 0, 4, 5, 2, 7, 3]     int64
# 21                                                [Y]    object
# 22                                          [Yes, No]    object
# 23                                                  -   float64
# 24                                    [3.0, 4.0, nan]   float64
# 25                                       [1, 4, 2, 3]     int64
# 26                                               [80]     int64
# 27                                       [0, 1, 3, 2]     int64
# 28                                                  -     int64
# 29                              [0, 3, 2, 5, 1, 4, 6]     int64
# 30                                       [1, 3, 2, 4]     int64
# 31                                                  -     int64
# 32                                                  -     int64
# 33                                                  -     int64
# 34                                                  -     int64

# %%
# Statistical Properties about the data
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# MonthlyIncome             1467.0   6505.155419  4711.297846  1009.0  2911.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1469.0   1025.556161   601.646166     1.0   492.00
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# MonthlyRate               1468.0  14310.966621  7121.294449  2094.0  8043.75
# NumCompaniesWorked        1470.0      2.693197     2.498009     0.0     1.00
# PercentSalaryHike         1469.0     15.206263     3.659047    11.0    12.00
# PerformanceRating         1469.0      3.153165     0.360270     3.0     3.00
# RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0     2.00
# StandardHours             1470.0     80.000000     0.000000    80.0    80.00
# StockOptionLevel          1470.0      0.793878     0.852077     0.0     0.00
# TotalWorkingYears         1470.0     11.279592     7.780782     0.0     6.00
# TrainingTimesLastYear     1470.0      2.799320     1.289271     0.0     2.00
# WorkLifeBalance           1470.0      2.761224     0.706476     1.0     2.00
# YearsAtCompany            1470.0      7.008163     6.126525     0.0     3.00
# YearsInCurrentRole        1470.0      4.229252     3.623137     0.0     2.00
# YearsSinceLastPromotion   1470.0      2.187755     3.222430     0.0     0.00
# YearsWithCurrManager      1470.0      4.123129     3.568136     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# MonthlyIncome              4908.0   8378.00  19999.0
# DailyRate                   802.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1022.0   1556.00   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyRate               14235.5  20463.25  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0

# %% [markdown]
# * From the output above we can get the averages of our numeric columns

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
# first method
print(f" maximum age: {df.Age.max()}\n minimum age: {df.Age.min()}\n average age: {df.Age.mean()}")
# Out:
#  maximum age: 60
#  minimum age: 18
#  average age: 36.923809523809524

# %%
# second method
age = df["Age"].agg(["min","max","mean"])
age
# Out:
# min     18.00000
# max     60.00000
# mean    36.92381
# Name: Age, dtype: float64

# %%
# third method
df[["Age"]].describe().T
# Out:
#       count      mean       std   min   25%   50%   75%   max
# Age  1470.0  36.92381  9.135373  18.0  30.0  36.0  43.0  60.0

# %% [markdown]
# # CODING TASK #2. DEALING WITH MISSING DATA

# %% [markdown]
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %%
# Let's locate rows that have Null values
df[df.isna().any(axis=1)]
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 6     59            NaN        No      Travel_Rarely       1324
# 7     30         2693.0        No      Travel_Rarely       1358
# 17    22         2935.0        No         Non-Travel       1123
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 6    Research & Development                 3          3            NaN
# 7                       NaN                24          1  Life Sciences
# 17   Research & Development                16          2        Medical
# 23   Research & Development                15          2  Life Sciences
# 103  Research & Development                 6          4          Other
# 947                   Sales                 5          3  Life Sciences
#
#      EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1                1  ...                         4             80
# 6                1  ...                         1             80
# 7                1  ...                         2             80
# 17               1  ...                         2             80
# 23               1  ...                         4             80
# 103              1  ...                         3             80
# 947              1  ...                         3             80
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1                  1                 10                      3
# 6                  3                 12                      3
# 7                  1                  1                      2
# 17                 2                  1                      2
# 23                 0                  0                      6
# 103                0                 16                      3
# 947                0                 10                      2
#
#      WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1                  3             10                   7
# 6                  2              1                   0
# 7                  3              1                   0
# 17                 2              1                   0
# 23                 3              0                   0
# 103                3             16                  13
# 947                2              8                   7
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 1                         1                     7
# 6                         0                     0
# 7                         0                     0
# 17                        0                     0
# 23                        0                     0
# 103                       2                    10
# 947                       7                     7
#
# [7 rows x 35 columns]

# %%
# Let's see the total number of missing elements per column
df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# let's just look at the missing features
df.isna().sum()[df.isna().sum() > 0]
# Out:
# MonthlyIncome        3
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
# Drop any row that contains a Null value
df.dropna(inplace = True)

# %%
# Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463
df.shape
# Out:
# (1463, 35)

# %%
# Let's check if we still have any missing values
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age, MonthlyIncome, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
# Let's read our csv file again for missing data analysis 
df = pd.read_csv("Human_Resources.csv")

# %%
# Calculate the average monthly income
df.MonthlyIncome.mean()
# Out:
# 6505.155419222904

# %%
# fill in the missing lines with the average monthly income
df["MonthlyIncome"].fillna(df.MonthlyIncome.mean(), inplace = True)

# %%
df["MonthlyIncome"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
df.MonthlyRate.median()
# Out:
# 14235.5

# %%
# Let's use the calculated median values to fill in the missing data
df["MonthlyRate"].fillna(df.MonthlyRate.median(), inplace = True)

# %%
df["MonthlyRate"].isnull().sum()
# Out:
# 0

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df.shape
# Out:
# (1467, 35)

# %% [markdown]
# # CODING TASK #3: PERFORM ONE-HOT ENCODING [OPTIONAL]

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
hr_df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
hr_df['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 1       Travel_Frequently
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
BusinessTravel_Encoded = pd.get_dummies(hr_df['BusinessTravel'])
print(BusinessTravel_Encoded)
# Out:
#       Non-Travel  Travel_Frequently  Travel_Rarely
# 0          False              False           True
# 1          False               True          False
# 2          False              False           True
# 3          False               True          False
# 4          False              False           True
# ...          ...                ...            ...
# 1465       False               True          False
# 1466       False              False           True
# 1467       False              False           True
# 1468       False               True          False
# 1469       False              False           True
#
# [1470 rows x 3 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %%
df = pd.read_csv('Human_Resources.csv')
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
#
# [3 rows x 35 columns]

# %%
df.dropna(inplace = True)

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age, MonthlyIncome, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
# Unique categories in the EducationField column
df.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
EducationField_Encoded = pd.get_dummies(df['EducationField'])
EducationField_Encoded
# Out:
#       Human Resources  Life Sciences  Marketing  Medical  Other  \
# 0               False           True      False    False  False
# 2               False          False      False    False   True
# 3               False           True      False    False  False
# 4               False          False      False     True  False
# 5               False           True      False    False  False
# ...               ...            ...        ...      ...    ...
# 1465            False          False      False     True  False
# 1466            False          False      False     True  False
# 1467            False           True      False    False  False
# 1468            False          False      False     True  False
# 1469            False          False      False     True  False
#
#       Technical Degree
# 0                False
# 2                False
# 3                False
# 4                False
# 5                False
# ...                ...
# 1465             False
# 1466             False
# 1467             False
# 1468             False
# 1469             False
#
# [1463 rows x 6 columns]

# %% [markdown]
# # CODING TASK #4: PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL]

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
hr_df['Age'].values
# Out:
# array([41, 49, 37, ..., 27, 49, 34], dtype=int64)

# %%
# !pip install scikit-learn

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))

# %%
hr_df['Age']
# Out:
# 0       0.547619
# 1       0.738095
# 2       0.452381
# 3       0.357143
# 4       0.214286
#           ...
# 1465    0.428571
# 1466    0.500000
# 1467    0.214286
# 1468    0.738095
# 1469    0.380952
# Name: Age, Length: 1470, dtype: float64

# %%
hr_df.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean      0.450567    6505.155419   802.485714          9.192517     2.912925
# std       0.217509    4711.297846   403.509100          8.106864     1.024165
# min       0.000000    1009.000000   102.000000          1.000000     1.000000
# 25%       0.285714    2911.000000   465.000000          2.000000     2.000000
# 50%       0.428571    4908.000000   802.000000          7.000000     3.000000
# 75%       0.595238    8378.000000  1157.000000         14.000000     4.000000
# max       1.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1469.000000              1470.000000  1470.000000
# mean             1.0     1025.556161                 2.721769    65.891156
# std              0.0      601.646166                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      492.000000                 2.000000    48.000000
# 50%              1.0     1022.000000                 3.000000    66.000000
# 75%              1.0     1556.000000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean         2.729932  ...                  2.712245           80.0
# std          0.711561  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%          2.000000  ...                  2.000000           80.0
# 50%          3.000000  ...                  3.000000           80.0
# 75%          3.000000  ...                  4.000000           80.0
# max          4.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %%
df = pd.read_csv('Human_Resources.csv')
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
#
# [3 rows x 35 columns]

# %%
# STANDARDIZATION
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.Age = scaler.fit_transform(df['Age'].values.reshape(-1,1))
df.Age
# Out:
# 0       0.446350
# 1       1.322365
# 2       0.008343
# 3      -0.429664
# 4      -1.086676
#           ...
# 1465   -0.101159
# 1466    0.227347
# 1467   -1.086676
# 1468    1.322365
# 1469   -0.320163
# Name: Age, Length: 1470, dtype: float64

# %%
df.Age.describe()
# Out:
# count    1.470000e+03
# mean    -3.504377e-17
# std      1.000340e+00
# min     -2.072192e+00
# 25%     -7.581700e-01
# 50%     -1.011589e-01
# 75%      6.653541e-01
# max      2.526886e+00
# Name: Age, dtype: float64

# %% [markdown]
# # CODING TASK #5. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
df = pd.read_csv('Human_Resources.csv')

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
df.TotalWorkingYears.value_counts()
# Out:
# TotalWorkingYears
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: count, dtype: int64

# %%
# Pull rows with Total Years of Employment greater than 25 
df[df.TotalWorkingYears >= 25]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 18     53        15427.0        No      Travel_Rarely       1219
# 25     53        19094.0        No      Travel_Rarely       1282
# 62     50        18740.0        No      Travel_Rarely        989
# 63     59         7637.0        No      Travel_Rarely       1435
# 67     45         9724.0        No      Travel_Rarely       1339
# ...   ...            ...       ...                ...        ...
# 1331   48        19665.0        No      Travel_Rarely       1224
# 1374   58        17875.0        No      Travel_Rarely        605
# 1377   49        19161.0        No  Travel_Frequently       1064
# 1401   55        19636.0        No      Travel_Rarely        189
# 1414   47         8633.0        No      Travel_Rarely       1180
#
#                   Department  DistanceFromHome  Education   EducationField  \
# 18                     Sales                 2          4    Life Sciences
# 25    Research & Development                 5          3            Other
# 62    Research & Development                 7          2          Medical
# 63                     Sales                25          3    Life Sciences
# 67    Research & Development                 7          3    Life Sciences
# ...                      ...               ...        ...              ...
# 1331  Research & Development                10          3    Life Sciences
# 1374                   Sales                21          3    Life Sciences
# 1377  Research & Development                 2          1    Life Sciences
# 1401         Human Resources                26          4  Human Resources
# 1414  Research & Development                25          3          Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 18                1  ...                         3             80
# 25                1  ...                         4             80
# 62                1  ...                         4             80
# 63                1  ...                         4             80
# 67                1  ...                         3             80
# ...             ...  ...                       ...            ...
# 1331              1  ...                         4             80
# 1374              1  ...                         3             80
# 1377              1  ...                         4             80
# 1401              1  ...                         1             80
# 1414              1  ...                         2             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 18                  0                 31                      3
# 25                  1                 26                      3
# 62                  1                 29                      2
# 63                  0                 28                      3
# 67                  1                 25                      2
# ...               ...                ...                    ...
# 1331                0                 29                      3
# 1374                1                 29                      2
# 1377                0                 28                      3
# 1401                1                 35                      0
# 1414                0                 25                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 18                  3             25                   8
# 25                  2             14                  13
# 62                  2             27                   3
# 63                  2             21                  16
# 67                  3              1                   0
# ...               ...            ...                 ...
# 1331                3             22                  10
# 1374                2              1                   0
# 1377                3              5                   4
# 1401                3             10                   9
# 1414                3             17                  14
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 18                         3                     7
# 25                         4                     8
# 62                        13                     8
# 63                         7                     9
# 67                         0                     0
# ...                      ...                   ...
# 1331                      12                     9
# 1374                       0                     0
# 1377                       4                     3
# 1401                       1                     4
# 1414                      12                    11
#
# [112 rows x 35 columns]

# %%
# Pull rows with a Total Years of Service greater than 25 and a gender of Female 
df[(df.TotalWorkingYears >= 25) & (df.Gender == "Female")]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 18     53        15427.0        No      Travel_Rarely       1219
# 25     53        19094.0        No      Travel_Rarely       1282
# 62     50        18740.0        No      Travel_Rarely        989
# 63     59         7637.0        No      Travel_Rarely       1435
# 105    59        18844.0        No         Non-Travel       1420
# 106    50        18172.0        No  Travel_Frequently       1115
# 126    58        10312.0       Yes      Travel_Rarely        147
# 233    50        19517.0        No      Travel_Rarely        854
# 263    46        16872.0        No      Travel_Rarely        488
# 316    49        13964.0        No      Travel_Rarely       1091
# 379    55        16659.0        No      Travel_Rarely       1311
# 401    56        13212.0        No  Travel_Frequently        906
# 408    52        16555.0        No      Travel_Rarely       1490
# 411    60        19566.0        No      Travel_Rarely        422
# 445    55        16835.0        No      Travel_Rarely       1117
# 465    46        10527.0        No  Travel_Frequently       1034
# 544    47        13770.0        No  Travel_Frequently        217
# 592    47        16752.0        No      Travel_Rarely        202
# 616    51        16307.0        No      Travel_Rarely       1318
# 624    53        10934.0        No      Travel_Rarely        661
# 627    52        13826.0        No  Travel_Frequently        890
# 649    53        14275.0        No      Travel_Rarely        102
# 677    49         7403.0        No      Travel_Rarely        527
# 743    59        13726.0        No      Travel_Rarely        715
# 749    52        19845.0       Yes      Travel_Rarely        266
# 755    45        17650.0        No      Travel_Rarely       1234
# 760    53         7525.0        No  Travel_Frequently        124
# 851    56        19943.0        No      Travel_Rarely        718
# 858    53        18606.0        No      Travel_Rarely       1223
# 861    46        17048.0        No      Travel_Rarely       1402
# 867    50        17856.0        No  Travel_Frequently       1421
# 890    54        10502.0        No  Travel_Frequently        966
# 913    45        18824.0       Yes      Travel_Rarely       1449
# 916    46        18789.0        No      Travel_Rarely        168
# 945    50        16880.0        No      Travel_Rarely       1322
# 966    58        10008.0       Yes      Travel_Rarely        601
# 971    51        13142.0        No      Travel_Rarely       1405
# 1008   54        17328.0        No      Travel_Rarely        971
# 1009   58        19701.0        No      Travel_Rarely       1055
# 1024   47        17169.0        No      Travel_Rarely        359
# 1076   54        16032.0        No  Travel_Frequently       1050
# 1111   53        10169.0       Yes      Travel_Rarely        607
# 1154   47        19658.0        No      Travel_Rarely       1176
# 1176   49        16413.0        No      Travel_Rarely        301
# 1181   49        13966.0        No      Travel_Rarely        465
# 1184   54        17426.0        No      Travel_Rarely        584
# 1194   47        15972.0        No      Travel_Rarely       1225
# 1268   53        12965.0        No         Non-Travel        661
# 1303   47        10333.0        No      Travel_Rarely       1001
# 1327   46        13225.0        No      Travel_Rarely       1319
# 1374   58        17875.0        No      Travel_Rarely        605
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 18                     Sales                 2          4     Life Sciences
# 25    Research & Development                 5          3             Other
# 62    Research & Development                 7          2           Medical
# 63                     Sales                25          3     Life Sciences
# 105          Human Resources                 2          4   Human Resources
# 106   Research & Development                 1          3     Life Sciences
# 126   Research & Development                23          4           Medical
# 233                    Sales                 1          4           Medical
# 263                    Sales                 2          3  Technical Degree
# 316   Research & Development                 1          2  Technical Degree
# 379   Research & Development                 2          3     Life Sciences
# 401                    Sales                 6          3     Life Sciences
# 408   Research & Development                 4          2     Life Sciences
# 411   Research & Development                 7          3     Life Sciences
# 445                    Sales                18          5     Life Sciences
# 465   Research & Development                18          1           Medical
# 544                    Sales                 3          3           Medical
# 592   Research & Development                 2          2             Other
# 616                    Sales                26          4         Marketing
# 624                    Sales                 7          2         Marketing
# 627   Research & Development                25          4           Medical
# 649   Research & Development                23          4     Life Sciences
# 677   Research & Development                 8          2             Other
# 743   Research & Development                 2          3     Life Sciences
# 749                    Sales                 2          1         Marketing
# 755                    Sales                11          2     Life Sciences
# 760                    Sales                 2          3         Marketing
# 851   Research & Development                 4          4  Technical Degree
# 858   Research & Development                 7          2           Medical
# 861                    Sales                 2          3         Marketing
# 867   Research & Development                 2          3           Medical
# 890   Research & Development                 1          4     Life Sciences
# 913                    Sales                 2          3         Marketing
# 916                    Sales                 4          2         Marketing
# 945   Research & Development                28          3     Life Sciences
# 966   Research & Development                 7          4           Medical
# 971   Research & Development                11          2  Technical Degree
# 1008  Research & Development                 1          3           Medical
# 1009  Research & Development                 1          3           Medical
# 1024  Research & Development                 2          4           Medical
# 1076  Research & Development                11          4           Medical
# 1111  Research & Development                 2          5  Technical Degree
# 1154         Human Resources                26          4     Life Sciences
# 1176  Research & Development                22          4             Other
# 1181  Research & Development                 6          1     Life Sciences
# 1184  Research & Development                22          5           Medical
# 1194                   Sales                 2          4     Life Sciences
# 1268  Research & Development                 1          4           Medical
# 1303  Research & Development                 4          3     Life Sciences
# 1327                   Sales                 3          3  Technical Degree
# 1374                   Sales                21          3     Life Sciences
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 18                1  ...                         3             80
# 25                1  ...                         4             80
# 62                1  ...                         4             80
# 63                1  ...                         4             80
# 105               1  ...                         4             80
# 106               1  ...                         1             80
# 126               1  ...                         4             80
# 233               1  ...                         3             80
# 263               1  ...                         2             80
# 316               1  ...                         4             80
# 379               1  ...                         3             80
# 401               1  ...                         4             80
# 408               1  ...                         4             80
# 411               1  ...                         4             80
# 445               1  ...                         4             80
# 465               1  ...                         4             80
# 544               1  ...                         4             80
# 592               1  ...                         3             80
# 616               1  ...                         3             80
# 624               1  ...                         4             80
# 627               1  ...                         3             80
# 649               1  ...                         3             80
# 677               1  ...                         3             80
# 743               1  ...                         1             80
# 749               1  ...                         4             80
# 755               1  ...                         2             80
# 760               1  ...                         1             80
# 851               1  ...                         4             80
# 858               1  ...                         2             80
# 861               1  ...                         1             80
# 867               1  ...                         3             80
# 890               1  ...                         1             80
# 913               1  ...                         1             80
# 916               1  ...                         3             80
# 945               1  ...                         2             80
# 966               1  ...                         4             80
# 971               1  ...                         2             80
# 1008              1  ...                         4             80
# 1009              1  ...                         3             80
# 1024              1  ...                         2             80
# 1076              1  ...                         1             80
# 1111              1  ...                         2             80
# 1154              1  ...                         3             80
# 1176              1  ...                         2             80
# 1181              1  ...                         2             80
# 1184              1  ...                         3             80
# 1194              1  ...                         3             80
# 1268              1  ...                         4             80
# 1303              1  ...                         3             80
# 1327              1  ...                         4             80
# 1374              1  ...                         3             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 18                  0                 31                      3
# 25                  1                 26                      3
# 62                  1                 29                      2
# 63                  0                 28                      3
# 105                 1                 30                      3
# 106                 0                 28                      1
# 126                 1                 40                      3
# 233                 1                 32                      3
# 263                 1                 28                      2
# 316                 0                 25                      2
# 379                 0                 30                      2
# 401                 3                 36                      0
# 408                 0                 31                      2
# 411                 0                 33                      5
# 445                 0                 37                      2
# 465                 0                 28                      3
# 544                 2                 28                      2
# 592                 1                 26                      3
# 616                 1                 29                      2
# 624                 1                 35                      3
# 627                 0                 31                      3
# 649                 0                 33                      0
# 677                 1                 29                      3
# 743                 0                 30                      4
# 749                 1                 33                      3
# 755                 1                 26                      4
# 760                 1                 30                      2
# 851                 1                 28                      2
# 858                 1                 26                      6
# 861                 0                 28                      2
# 867                 1                 32                      3
# 890                 1                 33                      2
# 913                 0                 26                      2
# 916                 1                 26                      2
# 945                 0                 25                      2
# 966                 0                 31                      0
# 971                 0                 29                      1
# 1008                0                 29                      3
# 1009                1                 32                      3
# 1024                2                 26                      2
# 1076                1                 26                      2
# 1111                1                 34                      4
# 1154                1                 27                      2
# 1176                2                 27                      2
# 1181                1                 30                      3
# 1184                1                 36                      6
# 1194                3                 29                      2
# 1268                3                 27                      2
# 1303                1                 28                      4
# 1327                1                 25                      5
# 1374                1                 29                      2
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 18                  3             25                   8
# 25                  2             14                  13
# 62                  2             27                   3
# 63                  2             21                  16
# 105                 3              3                   2
# 106                 2              8                   3
# 126                 2             40                  10
# 233                 2              7                   0
# 263                 2              7                   7
# 316                 3              7                   1
# 379                 3              5                   4
# 401                 2              7                   7
# 408                 1              5                   2
# 411                 1             29                   8
# 445                 3             10                   9
# 465                 2              2                   2
# 544                 2             22                   2
# 592                 2             26                  14
# 616                 2             20                   6
# 624                 3              5                   2
# 627                 3              9                   8
# 649                 3             12                   9
# 677                 2             26                   9
# 743                 3              5                   3
# 749                 3             32                  14
# 755                 4              9                   3
# 760                 3             15                   7
# 851                 3              5                   2
# 858                 3              7                   7
# 861                 3             26                  15
# 867                 3              2                   2
# 890                 1              5                   4
# 913                 3             24                  10
# 916                 3             11                   4
# 945                 3              3                   2
# 966                 2             10                   9
# 971                 2              5                   2
# 1008                2             20                   7
# 1009                3              9                   8
# 1024                4             20                  17
# 1076                3             14                   9
# 1111                3             33                   7
# 1154                3              5                   2
# 1176                3              4                   2
# 1181                3             15                  11
# 1184                3             10                   8
# 1194                3              3                   2
# 1268                2              3                   2
# 1303                3             22                  11
# 1327                3             19                  17
# 1374                2              1                   0
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 18                         3                     7
# 25                         4                     8
# 62                        13                     8
# 63                         7                     9
# 105                        2                     2
# 106                        0                     7
# 126                       15                     6
# 233                        0                     6
# 263                        7                     7
# 316                        0                     7
# 379                        1                     2
# 401                        7                     7
# 408                        1                     4
# 411                       11                    10
# 445                        7                     7
# 465                        1                     2
# 544                       11                    13
# 592                        3                     0
# 616                        4                    17
# 624                        0                     4
# 627                        0                     0
# 649                        3                     8
# 677                        1                     7
# 743                        4                     3
# 749                        6                     9
# 755                        1                     1
# 760                        6                    12
# 851                        4                     2
# 858                        4                     7
# 861                       15                     9
# 867                        2                     2
# 890                        1                     4
# 913                        1                    11
# 916                        0                     8
# 945                        1                     2
# 966                        5                     9
# 971                        0                     3
# 1008                      12                     7
# 1009                       1                     5
# 1024                       5                     6
# 1076                       1                    12
# 1111                       1                     9
# 1154                       1                     0
# 1176                       1                     2
# 1181                       2                    12
# 1184                       4                     7
# 1194                       1                     2
# 1268                       0                     2
# 1303                      14                    10
# 1327                       2                     8
# 1374                       0                     0
#
# [51 rows x 35 columns]

# %%
# Let's retrieve values that fall between a certain range in total working years 
df[(df['TotalWorkingYears'] >= 35) & (df['TotalWorkingYears'] <= 40)]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 85     56         7260.0        No      Travel_Rarely       1400
# 98     58        13872.0        No      Travel_Rarely        682
# 126    58        10312.0       Yes      Travel_Rarely        147
# 187    55        18722.0        No      Travel_Rarely        692
# 270    55        19045.0        No      Travel_Rarely        452
# 401    56        13212.0        No  Travel_Frequently        906
# 445    55        16835.0        No      Travel_Rarely       1117
# 595    58        19246.0       Yes      Travel_Rarely        286
# 624    53        10934.0        No      Travel_Rarely        661
# 894    54        17779.0        No      Travel_Rarely        685
# 956    56        19717.0        No      Travel_Rarely        206
# 1043   53        16598.0        No      Travel_Rarely        447
# 1116   55        19586.0        No      Travel_Rarely        685
# 1184   54        17426.0        No      Travel_Rarely        584
# 1301   58        16291.0        No         Non-Travel        350
# 1401   55        19636.0        No      Travel_Rarely        189
#
#                   Department  DistanceFromHome  Education   EducationField  \
# 85    Research & Development                 7          3    Life Sciences
# 98                     Sales                10          4          Medical
# 126   Research & Development                23          4          Medical
# 187   Research & Development                14          4          Medical
# 270   Research & Development                 1          3          Medical
# 401                    Sales                 6          3    Life Sciences
# 445                    Sales                18          5    Life Sciences
# 595   Research & Development                 2          4    Life Sciences
# 624                    Sales                 7          2        Marketing
# 894   Research & Development                 3          3    Life Sciences
# 956          Human Resources                 8          4    Life Sciences
# 1043  Research & Development                 2          3          Medical
# 1116                   Sales                26          5        Marketing
# 1184  Research & Development                22          5          Medical
# 1301                   Sales                 2          3          Medical
# 1401         Human Resources                26          4  Human Resources
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 85                1  ...                         1             80
# 98                1  ...                         3             80
# 126               1  ...                         4             80
# 187               1  ...                         4             80
# 270               1  ...                         3             80
# 401               1  ...                         4             80
# 445               1  ...                         4             80
# 595               1  ...                         4             80
# 624               1  ...                         4             80
# 894               1  ...                         1             80
# 956               1  ...                         1             80
# 1043              1  ...                         2             80
# 1116              1  ...                         3             80
# 1184              1  ...                         3             80
# 1301              1  ...                         4             80
# 1401              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 85                  0                 37                      3
# 98                  0                 38                      1
# 126                 1                 40                      3
# 187                 0                 36                      3
# 270                 0                 37                      2
# 401                 3                 36                      0
# 445                 0                 37                      2
# 595                 0                 40                      2
# 624                 1                 35                      3
# 894                 0                 36                      2
# 956                 0                 36                      4
# 1043                0                 35                      2
# 1116                1                 36                      3
# 1184                1                 36                      6
# 1301                1                 37                      0
# 1401                1                 35                      0
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 85                  2              6                   4
# 98                  2             37                  10
# 126                 2             40                  10
# 187                 3             24                  15
# 270                 3             36                  10
# 401                 2              7                   7
# 445                 3             10                   9
# 595                 3             31                  15
# 624                 3              5                   2
# 894                 3             10                   9
# 956                 3              7                   3
# 1043                2              9                   8
# 1116                3             36                   6
# 1184                3             10                   8
# 1301                2             16                   9
# 1401                3             10                   9
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 85                         0                     2
# 98                         1                     8
# 126                       15                     6
# 187                        2                    15
# 270                        4                    13
# 401                        7                     7
# 445                        7                     7
# 595                       13                     8
# 624                        0                     4
# 894                        0                     9
# 956                        7                     7
# 1043                       8                     8
# 1116                       2                    13
# 1184                       4                     7
# 1301                      14                    14
# 1401                       1                     4
#
# [16 rows x 35 columns]

# %%
# Second way
df.query('TotalWorkingYears >= 35 and TotalWorkingYears <= 40')
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 85     56         7260.0        No      Travel_Rarely       1400
# 98     58        13872.0        No      Travel_Rarely        682
# 126    58        10312.0       Yes      Travel_Rarely        147
# 187    55        18722.0        No      Travel_Rarely        692
# 270    55        19045.0        No      Travel_Rarely        452
# 401    56        13212.0        No  Travel_Frequently        906
# 445    55        16835.0        No      Travel_Rarely       1117
# 595    58        19246.0       Yes      Travel_Rarely        286
# 624    53        10934.0        No      Travel_Rarely        661
# 894    54        17779.0        No      Travel_Rarely        685
# 956    56        19717.0        No      Travel_Rarely        206
# 1043   53        16598.0        No      Travel_Rarely        447
# 1116   55        19586.0        No      Travel_Rarely        685
# 1184   54        17426.0        No      Travel_Rarely        584
# 1301   58        16291.0        No         Non-Travel        350
# 1401   55        19636.0        No      Travel_Rarely        189
#
#                   Department  DistanceFromHome  Education   EducationField  \
# 85    Research & Development                 7          3    Life Sciences
# 98                     Sales                10          4          Medical
# 126   Research & Development                23          4          Medical
# 187   Research & Development                14          4          Medical
# 270   Research & Development                 1          3          Medical
# 401                    Sales                 6          3    Life Sciences
# 445                    Sales                18          5    Life Sciences
# 595   Research & Development                 2          4    Life Sciences
# 624                    Sales                 7          2        Marketing
# 894   Research & Development                 3          3    Life Sciences
# 956          Human Resources                 8          4    Life Sciences
# 1043  Research & Development                 2          3          Medical
# 1116                   Sales                26          5        Marketing
# 1184  Research & Development                22          5          Medical
# 1301                   Sales                 2          3          Medical
# 1401         Human Resources                26          4  Human Resources
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 85                1  ...                         1             80
# 98                1  ...                         3             80
# 126               1  ...                         4             80
# 187               1  ...                         4             80
# 270               1  ...                         3             80
# 401               1  ...                         4             80
# 445               1  ...                         4             80
# 595               1  ...                         4             80
# 624               1  ...                         4             80
# 894               1  ...                         1             80
# 956               1  ...                         1             80
# 1043              1  ...                         2             80
# 1116              1  ...                         3             80
# 1184              1  ...                         3             80
# 1301              1  ...                         4             80
# 1401              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 85                  0                 37                      3
# 98                  0                 38                      1
# 126                 1                 40                      3
# 187                 0                 36                      3
# 270                 0                 37                      2
# 401                 3                 36                      0
# 445                 0                 37                      2
# 595                 0                 40                      2
# 624                 1                 35                      3
# 894                 0                 36                      2
# 956                 0                 36                      4
# 1043                0                 35                      2
# 1116                1                 36                      3
# 1184                1                 36                      6
# 1301                1                 37                      0
# 1401                1                 35                      0
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 85                  2              6                   4
# 98                  2             37                  10
# 126                 2             40                  10
# 187                 3             24                  15
# 270                 3             36                  10
# 401                 2              7                   7
# 445                 3             10                   9
# 595                 3             31                  15
# 624                 3              5                   2
# 894                 3             10                   9
# 956                 3              7                   3
# 1043                2              9                   8
# 1116                3             36                   6
# 1184                3             10                   8
# 1301                2             16                   9
# 1401                3             10                   9
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 85                         0                     2
# 98                         1                     8
# 126                       15                     6
# 187                        2                    15
# 270                        4                    13
# 401                        7                     7
# 445                        7                     7
# 595                       13                     8
# 624                        0                     4
# 894                        0                     9
# 956                        7                     7
# 1043                       8                     8
# 1116                       2                    13
# 1184                       4                     7
# 1301                      14                    14
# 1401                       1                     4
#
# [16 rows x 35 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
df_1450_ = df[df.DailyRate >= 1450]

# %%
df_1450_.shape
# Out:
# (50, 35)

# %%
df_1450_.head()
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 31    44         6465.0        No      Travel_Rarely       1459
# 52    44         5454.0        No      Travel_Rarely       1488
# 110   51         7484.0        No  Travel_Frequently       1456
# 117   36         9738.0        No  Travel_Frequently       1467
# 155   29         4319.0        No         Non-Travel       1496
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 31   Research & Development                10          4             Other
# 52                    Sales                 1          5         Marketing
# 110  Research & Development                 1          4           Medical
# 117                   Sales                11          2  Technical Degree
# 155  Research & Development                 1          1  Technical Degree
#
#      EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 31               1  ...                         4             80
# 52               1  ...                         3             80
# 110              1  ...                         3             80
# 117              1  ...                         3             80
# 155              1  ...                         1             80
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 31                 0                  9                      5
# 52                 1                  9                      2
# 110                0                 23                      1
# 117                1                 10                      6
# 155                1                 10                      1
#
#      WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 31                 4              4                   2
# 52                 2              4                   3
# 110                2             13                  12
# 117                3              9                   7
# 155                3             10                   7
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 31                        1                     3
# 52                        1                     3
# 110                      12                     8
# 117                       2                     8
# 155                       0                     9
#
# [5 rows x 35 columns]

# %%
df_1450_.DailyRate.mean()
# Out:
# 1474.98

# %%
# What is the combined Daily Rate for all employees with 1450+?????

# %%
df_1450_.DailyRate.sum()
# Out:
# 73749

# %% [markdown]
# # CODING TASK #6: PERFORM BASIC EDA ON BOTH CLASSES

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
df = pd.read_csv('Human_Resources.csv')

# %%
df.shape
# Out:
# (1470, 35)

# %%
# Drop the 'EmployeeCount', 'Standardhours' and 'Over18' columns
df.drop(['EmployeeCount', 'StandardHours', 'Over18'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (1470, 32)

# %%
df.Attrition.value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df.drop(['EmployeeNumber'], axis = 1, inplace = True)

# %%
# Let's view the departing employees
df_yes = df[df.Attrition == "Yes"]
df_yes
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 14     28         2028.0       Yes      Travel_Rarely        103
# 21     36         3407.0       Yes      Travel_Rarely       1218
# 24     34         2960.0       Yes      Travel_Rarely        699
# ...   ...            ...       ...                ...        ...
# 1438   23         1790.0       Yes  Travel_Frequently        638
# 1442   29         4787.0       Yes      Travel_Rarely       1092
# 1444   56         2339.0       Yes      Travel_Rarely        310
# 1452   50         6728.0       Yes  Travel_Frequently        878
# 1461   50        10854.0       Yes      Travel_Rarely        410
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                      Sales                 1          2     Life Sciences
# 2     Research & Development                 2          2             Other
# 14    Research & Development                24          3     Life Sciences
# 21                     Sales                 9          4     Life Sciences
# 24    Research & Development                 6          1           Medical
# ...                      ...               ...        ...               ...
# 1438                   Sales                 9          3         Marketing
# 1442  Research & Development                 1          4           Medical
# 1444  Research & Development                 7          2  Technical Degree
# 1452                   Sales                 1          4     Life Sciences
# 1461                   Sales                28          3         Marketing
#
#       EnvironmentSatisfaction  ... PerformanceRating  \
# 0                           2  ...               3.0
# 2                           4  ...               3.0
# 14                          3  ...               3.0
# 21                          3  ...               4.0
# 24                          2  ...               3.0
# ...                       ...  ...               ...
# 1438                        4  ...               3.0
# 1442                        1  ...               3.0
# 1444                        4  ...               3.0
# 1452                        2  ...               3.0
# 1461                        4  ...               3.0
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                            1                 0                  8
# 2                            2                 0                  7
# 14                           2                 0                  6
# 21                           2                 0                 10
# 24                           3                 0                  8
# ...                        ...               ...                ...
# 1438                         1                 1                  1
# 1442                         2                 3                  4
# 1444                         4                 1                 14
# 1452                         4                 2                 12
# 1461                         2                 1                 20
#
#      TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                        0                1              6
# 2                        3                3              0
# 14                       4                3              4
# 21                       4                3              5
# 24                       2                3              4
# ...                    ...              ...            ...
# 1438                     3                2              1
# 1442                     3                4              2
# 1444                     4                1             10
# 1452                     3                3              6
# 1461                     3                3              3
#
#       YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                      4                        0                    5
# 2                      0                        0                    0
# 14                     2                        0                    3
# 21                     3                        0                    3
# 24                     2                        1                    3
# ...                  ...                      ...                  ...
# 1438                   0                        1                    0
# 1442                   2                        2                    2
# 1444                   9                        9                    8
# 1452                   3                        0                    1
# 1461                   2                        2                    0
#
# [237 rows x 31 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
df_no = df[df.Attrition == "No"]
df_no
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1      49            NaN        No  Travel_Frequently        279
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# 6      59            NaN        No      Travel_Rarely       1324
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1     Research & Development                 8          1  Life Sciences
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# 5     Research & Development                 2          2  Life Sciences
# 6     Research & Development                 3          3            NaN
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EnvironmentSatisfaction  ... PerformanceRating  \
# 1                           3  ...               4.0
# 3                           4  ...               3.0
# 4                           1  ...               3.0
# 5                           4  ...               3.0
# 6                           3  ...               NaN
# ...                       ...  ...               ...
# 1465                        3  ...               3.0
# 1466                        4  ...               3.0
# 1467                        2  ...               4.0
# 1468                        4  ...               3.0
# 1469                        2  ...               3.0
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 1                            4                 1                 10
# 3                            3                 0                  8
# 4                            4                 1                  6
# 5                            3                 0                  8
# 6                            1                 3                 12
# ...                        ...               ...                ...
# 1465                         3                 1                 17
# 1466                         1                 1                  9
# 1467                         2                 1                  6
# 1468                         4                 0                 17
# 1469                         1                 0                  6
#
#      TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 1                        3                3             10
# 3                        3                3              8
# 4                        3                3              2
# 5                        2                2              7
# 6                        3                2              1
# ...                    ...              ...            ...
# 1465                     3                3              5
# 1466                     5                3              7
# 1467                     0                3              6
# 1468                     3                2              9
# 1469                     3                4              4
#
#       YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 1                      7                        1                    7
# 3                      7                        3                    0
# 4                      2                        2                    2
# 5                      7                        3                    6
# 6                      0                        0                    0
# ...                  ...                      ...                  ...
# 1465                   2                        0                    3
# 1466                   7                        1                    7
# 1467                   2                        0                    3
# 1468                   6                        0                    8
# 1469                   3                        1                    2
#
# [1233 rows x 31 columns]

# %%
# istatistic information of employees who continue to work
df_no.describe().T
# Out:
#                            count          mean          std     min     25%  \
# Age                       1233.0     37.561233     8.888360    18.0    31.0
# MonthlyIncome             1231.0   6837.504468  4820.415800  1051.0  3211.5
# DailyRate                 1233.0    812.504461   403.208379   102.0   477.0
# DistanceFromHome          1233.0      8.915653     8.012633     1.0     2.0
# Education                 1233.0      2.927007     1.027002     1.0     2.0
# EnvironmentSatisfaction   1233.0      2.771290     1.071132     1.0     2.0
# HourlyRate                1233.0     65.952149    20.380754    30.0    48.0
# JobInvolvement            1233.0      2.770479     0.692050     1.0     2.0
# JobLevel                  1233.0      2.145985     1.117933     1.0     1.0
# JobSatisfaction           1233.0      2.778589     1.093277     1.0     2.0
# MonthlyRate               1231.0  14263.154346  7106.411508  2094.0  7961.5
# NumCompaniesWorked        1233.0      2.645580     2.460090     0.0     1.0
# PercentSalaryHike         1232.0     15.227273     3.638449    11.0    12.0
# PerformanceRating         1232.0      3.152597     0.359745     3.0     3.0
# RelationshipSatisfaction  1233.0      2.733982     1.071603     1.0     2.0
# StockOptionLevel          1233.0      0.845093     0.841985     0.0     0.0
# TotalWorkingYears         1233.0     11.862936     7.760719     0.0     6.0
# TrainingTimesLastYear     1233.0      2.832928     1.293585     0.0     2.0
# WorkLifeBalance           1233.0      2.781022     0.681907     1.0     2.0
# YearsAtCompany            1233.0      7.369019     6.096298     0.0     3.0
# YearsInCurrentRole        1233.0      4.484185     3.649402     0.0     2.0
# YearsSinceLastPromotion   1233.0      2.234388     3.234762     0.0     0.0
# YearsWithCurrManager      1233.0      4.367397     3.594116     0.0     2.0
#
#                               50%      75%      max
# Age                          36.0     43.0     60.0
# MonthlyIncome              5206.0   8835.5  19999.0
# DailyRate                   817.0   1176.0   1499.0
# DistanceFromHome              7.0     13.0     29.0
# Education                     3.0      4.0      5.0
# EnvironmentSatisfaction       3.0      4.0      4.0
# HourlyRate                   66.0     83.0    100.0
# JobInvolvement                3.0      3.0      4.0
# JobLevel                      2.0      3.0      5.0
# JobSatisfaction               3.0      4.0      4.0
# MonthlyRate               14120.0  20378.0  26997.0
# NumCompaniesWorked            2.0      4.0      9.0
# PercentSalaryHike            14.0     18.0     25.0
# PerformanceRating             3.0      3.0      4.0
# RelationshipSatisfaction      3.0      4.0      4.0
# StockOptionLevel              1.0      1.0      3.0
# TotalWorkingYears            10.0     16.0     38.0
# TrainingTimesLastYear         3.0      3.0      6.0
# WorkLifeBalance               3.0      3.0      4.0
# YearsAtCompany                6.0     10.0     37.0
# YearsInCurrentRole            3.0      7.0     18.0
# YearsSinceLastPromotion       1.0      3.0     15.0
# YearsWithCurrManager          3.0      7.0     17.0

# %%
# istatistic information of departing employees
df_yes.describe().T
# Out:
#                           count          mean          std     min     25%  \
# Age                       237.0     33.607595     9.689350    18.0    28.0
# MonthlyIncome             236.0   4771.588983  3640.097444  1009.0  2371.5
# DailyRate                 237.0    750.362869   401.899519   103.0   408.0
# DistanceFromHome          237.0     10.632911     8.452525     1.0     3.0
# Education                 237.0      2.839662     1.008244     1.0     2.0
# EnvironmentSatisfaction   237.0      2.464135     1.169791     1.0     1.0
# HourlyRate                237.0     65.573840    20.099958    31.0    50.0
# JobInvolvement            237.0      2.518987     0.773405     1.0     2.0
# JobLevel                  237.0      1.637131     0.940594     1.0     1.0
# JobSatisfaction           237.0      2.468354     1.118058     1.0     1.0
# MonthlyRate               237.0  14559.308017  7208.153264  2326.0  8870.0
# NumCompaniesWorked        237.0      2.940928     2.678519     0.0     1.0
# PercentSalaryHike         237.0     15.097046     3.770294    11.0    12.0
# PerformanceRating         237.0      3.156118     0.363735     3.0     3.0
# RelationshipSatisfaction  237.0      2.599156     1.125437     1.0     2.0
# StockOptionLevel          237.0      0.527426     0.856361     0.0     0.0
# TotalWorkingYears         237.0      8.244726     7.169204     0.0     3.0
# TrainingTimesLastYear     237.0      2.624473     1.254784     0.0     2.0
# WorkLifeBalance           237.0      2.658228     0.816453     1.0     2.0
# YearsAtCompany            237.0      5.130802     5.949984     0.0     1.0
# YearsInCurrentRole        237.0      2.902954     3.174827     0.0     0.0
# YearsSinceLastPromotion   237.0      1.945148     3.153077     0.0     0.0
# YearsWithCurrManager      237.0      2.852321     3.143349     0.0     0.0
#
#                               50%      75%      max
# Age                          32.0     39.0     58.0
# MonthlyIncome              3187.0   5850.0  19859.0
# DailyRate                   699.0   1092.0   1496.0
# DistanceFromHome              9.0     17.0     29.0
# Education                     3.0      4.0      5.0
# EnvironmentSatisfaction       3.0      4.0      4.0
# HourlyRate                   66.0     84.0    100.0
# JobInvolvement                3.0      3.0      4.0
# JobLevel                      1.0      2.0      5.0
# JobSatisfaction               3.0      3.0      4.0
# MonthlyRate               14618.0  21081.0  26999.0
# NumCompaniesWorked            1.0      5.0      9.0
# PercentSalaryHike            14.0     17.0     25.0
# PerformanceRating             3.0      3.0      4.0
# RelationshipSatisfaction      3.0      4.0      4.0
# StockOptionLevel              0.0      1.0      3.0
# TotalWorkingYears             7.0     10.0     40.0
# TrainingTimesLastYear         2.0      3.0      6.0
# WorkLifeBalance               3.0      3.0      4.0
# YearsAtCompany                3.0      7.0     40.0
# YearsInCurrentRole            2.0      4.0     15.0
# YearsSinceLastPromotion       1.0      2.0     15.0
# YearsWithCurrManager          2.0      5.0     14.0

# %% [markdown]
# * from the information above:
#
# 1- The level of job satisfaction is lower among separated employees
#
# 2- Monthly income is lower for employees who quit their jobs
#
# 3- Total years of employment is lower for employees who quit
#
# 4- Job level is lower for employees who quit
#
# * As can be seen, there are many cause and effect relationships for employees who leave their jobs

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %%
df.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.DailyRate[:5]
# Out:
# 0    1102
# 1     279
# 2    1373
# 3    1392
# 4     591
# Name: DailyRate, dtype: int64

# %%
df.DailyRate = df.DailyRate * 1.1

# %%
df.DailyRate[:5]
# Out:
# 0    1212.2
# 1     306.9
# 2    1510.3
# 3    1531.2
# 4     650.1
# Name: DailyRate, dtype: float64

# %%
# Let's do the above operations with the function

def New_DailyRate(x):
    New_DailyRate = x*1.1
    return New_DailyRate

New_DailyRate(df["DailyRate"])
# Out:
# 0       1333.42
# 1        337.59
# 2       1661.33
# 3       1684.32
# 4        715.11
#          ...
# 1465    1069.64
# 1466     741.73
# 1467     187.55
# 1468    1237.83
# 1469     759.88
# Name: DailyRate, Length: 1470, dtype: float64

# %% [markdown]
# **PRACTICE OPPORTUNITY #7:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %%
def New2_DailyRate(x):
    New_DailyRate = x*2 + 100
    return New_DailyRate

df["DailyRate"] = New2_DailyRate(df["DailyRate"])
df["DailyRate"]
# Out:
# 0       2524.4
# 1        713.8
# 2       3120.6
# 3       3162.4
# 4       1400.2
#          ...
# 1465    2044.8
# 1466    1448.6
# 1467     441.0
# 1468    2350.6
# 1469    1481.6
# Name: DailyRate, Length: 1470, dtype: float64

# %% [markdown]
# # CODING TASK #8: HISTOGRAM AND CORRELATION

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Let's fetch columns with unique values greater than 40 and look at their distribution
df_con = ["MonthlyIncome","TotalWorkingYears"]
df_con
# Out:
# ['MonthlyIncome', 'TotalWorkingYears']

# %%
# with histogram
for i in df_con:
    sns.histplot(data = df, x = i, fill = True, linewidth = 2)
    plt.show()

# %%
# with kdeplot
for i in df_con:
    sns.kdeplot(data = df, x = i, fill = True, linewidth = 2)
    plt.show()

# %%
df.select_dtypes('number').corr()
# Out:
#                                Age  MonthlyIncome  DailyRate  \
# Age                       1.000000       0.500915   0.010661
# MonthlyIncome             0.500915       1.000000   0.008020
# DailyRate                 0.010661       0.008020   1.000000
# DistanceFromHome         -0.001686      -0.017333  -0.004985
# Education                 0.208034       0.094755  -0.016806
# EnvironmentSatisfaction   0.010146      -0.005885   0.018355
# HourlyRate                0.024287      -0.015412   0.023381
# JobInvolvement            0.029820      -0.014619   0.046135
# JobLevel                  0.509604       0.950346   0.002966
# JobSatisfaction          -0.004892      -0.007983   0.030571
# MonthlyRate               0.028860       0.035034  -0.031775
# NumCompaniesWorked        0.299635       0.149371   0.038153
# PercentSalaryHike         0.001483      -0.026485   0.021576
# PerformanceRating        -0.001965      -0.015297  -0.001595
# RelationshipSatisfaction  0.053535       0.025200   0.007846
# StockOptionLevel          0.037510       0.007174   0.042143
# TotalWorkingYears         0.680381       0.773216   0.014515
# TrainingTimesLastYear    -0.019621      -0.021455   0.002453
# WorkLifeBalance          -0.021490       0.030490  -0.037848
# YearsAtCompany            0.311309       0.514168  -0.034055
# YearsInCurrentRole        0.212901       0.363535   0.009932
# YearsSinceLastPromotion   0.216513       0.344548  -0.033229
# YearsWithCurrManager      0.202089       0.343788  -0.026363
#
#                           DistanceFromHome  Education  \
# Age                              -0.001686   0.208034
# MonthlyIncome                    -0.017333   0.094755
# DailyRate                        -0.004985  -0.016806
# DistanceFromHome                  1.000000   0.021042
# Education                         0.021042   1.000000
# EnvironmentSatisfaction          -0.016075  -0.027128
# HourlyRate                        0.031131   0.016775
# JobInvolvement                    0.008783   0.042438
# JobLevel                          0.005303   0.101589
# JobSatisfaction                  -0.003669  -0.011296
# MonthlyRate                       0.027075  -0.025496
# NumCompaniesWorked               -0.029251   0.126317
# PercentSalaryHike                 0.040948  -0.011193
# PerformanceRating                 0.028389  -0.024721
# RelationshipSatisfaction          0.006557  -0.009118
# StockOptionLevel                  0.044872   0.018422
# TotalWorkingYears                 0.004628   0.148280
# TrainingTimesLastYear            -0.036942  -0.025100
# WorkLifeBalance                  -0.026556   0.009819
# YearsAtCompany                    0.009508   0.069114
# YearsInCurrentRole                0.018845   0.060236
# YearsSinceLastPromotion           0.010029   0.054254
# YearsWithCurrManager              0.014406   0.069065
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.010146    0.024287        0.029820
# MonthlyIncome                           -0.005885   -0.015412       -0.014619
# DailyRate                                0.018355    0.023381        0.046135
# DistanceFromHome                        -0.016075    0.031131        0.008783
# Education                               -0.027128    0.016775        0.042438
# EnvironmentSatisfaction                  1.000000   -0.049857       -0.008278
# HourlyRate                              -0.049857    1.000000        0.042861
# JobInvolvement                          -0.008278    0.042861        1.000000
# JobLevel                                 0.001212   -0.027853       -0.012630
# JobSatisfaction                         -0.006784   -0.071335       -0.021476
# MonthlyRate                              0.037242   -0.016238       -0.016441
# NumCompaniesWorked                       0.012594    0.022157        0.015012
# PercentSalaryHike                       -0.031947   -0.009732       -0.018827
# PerformanceRating                       -0.030012   -0.003366       -0.032018
# RelationshipSatisfaction                 0.007665    0.001330        0.034297
# StockOptionLevel                         0.003432    0.050263        0.021523
# TotalWorkingYears                       -0.002693   -0.002334       -0.005533
# TrainingTimesLastYear                   -0.019359   -0.008548       -0.015338
# WorkLifeBalance                          0.027627   -0.004607       -0.014617
# YearsAtCompany                           0.001458   -0.019582       -0.021355
# YearsInCurrentRole                       0.018007   -0.024106        0.008717
# YearsSinceLastPromotion                  0.016194   -0.026716       -0.024184
# YearsWithCurrManager                    -0.004999   -0.020123        0.025976
#
#                           JobLevel  JobSatisfaction  ...  PerformanceRating  \
# Age                       0.509604        -0.004892  ...          -0.001965
# MonthlyIncome             0.950346        -0.007983  ...          -0.015297
# DailyRate                 0.002966         0.030571  ...          -0.001595
# DistanceFromHome          0.005303        -0.003669  ...           0.028389
# Education                 0.101589        -0.011296  ...          -0.024721
# EnvironmentSatisfaction   0.001212        -0.006784  ...          -0.030012
# HourlyRate               -0.027853        -0.071335  ...          -0.003366
# JobInvolvement           -0.012630        -0.021476  ...          -0.032018
# JobLevel                  1.000000        -0.001944  ...          -0.019730
# JobSatisfaction          -0.001944         1.000000  ...           0.004814
# MonthlyRate               0.040030         0.000139  ...          -0.008728
# NumCompaniesWorked        0.142501        -0.055699  ...          -0.014960
# PercentSalaryHike        -0.033904         0.021430  ...           0.773360
# PerformanceRating        -0.019730         0.004814  ...           1.000000
# RelationshipSatisfaction  0.021642        -0.012454  ...          -0.028900
# StockOptionLevel          0.013984         0.010690  ...          -0.000633
# TotalWorkingYears         0.782208        -0.020185  ...           0.006608
# TrainingTimesLastYear    -0.018191        -0.005779  ...          -0.015857
# WorkLifeBalance           0.037818        -0.019459  ...           0.004304
# YearsAtCompany            0.534739        -0.003803  ...           0.005013
# YearsInCurrentRole        0.389447        -0.002305  ...           0.036938
# YearsSinceLastPromotion   0.353885        -0.018214  ...           0.019019
# YearsWithCurrManager      0.375281        -0.027656  ...           0.024731
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.053535          0.037510
# MonthlyIncome                             0.025200          0.007174
# DailyRate                                 0.007846          0.042143
# DistanceFromHome                          0.006557          0.044872
# Education                                -0.009118          0.018422
# EnvironmentSatisfaction                   0.007665          0.003432
# HourlyRate                                0.001330          0.050263
# JobInvolvement                            0.034297          0.021523
# JobLevel                                  0.021642          0.013984
# JobSatisfaction                          -0.012454          0.010690
# MonthlyRate                              -0.004608         -0.034070
# NumCompaniesWorked                        0.052733          0.030075
# PercentSalaryHike                        -0.039134          0.005234
# PerformanceRating                        -0.028900         -0.000633
# RelationshipSatisfaction                  1.000000         -0.045952
# StockOptionLevel                         -0.045952          1.000000
# TotalWorkingYears                         0.024054          0.010136
# TrainingTimesLastYear                     0.002497          0.011274
# WorkLifeBalance                           0.019604          0.004129
# YearsAtCompany                            0.019367          0.015058
# YearsInCurrentRole                       -0.015123          0.050818
# YearsSinceLastPromotion                   0.033493          0.014352
# YearsWithCurrManager                     -0.000867          0.024698
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.680381              -0.019621
# MonthlyIncome                      0.773216              -0.021455
# DailyRate                          0.014515               0.002453
# DistanceFromHome                   0.004628              -0.036942
# Education                          0.148280              -0.025100
# EnvironmentSatisfaction           -0.002693              -0.019359
# HourlyRate                        -0.002334              -0.008548
# JobInvolvement                    -0.005533              -0.015338
# JobLevel                           0.782208              -0.018191
# JobSatisfaction                   -0.020185              -0.005779
# MonthlyRate                        0.027266               0.000315
# NumCompaniesWorked                 0.237639              -0.066054
# PercentSalaryHike                 -0.020703              -0.005363
# PerformanceRating                  0.006608              -0.015857
# RelationshipSatisfaction           0.024054               0.002497
# StockOptionLevel                   0.010136               0.011274
# TotalWorkingYears                  1.000000              -0.035662
# TrainingTimesLastYear             -0.035662               1.000000
# WorkLifeBalance                    0.001008               0.028072
# YearsAtCompany                     0.628133               0.003569
# YearsInCurrentRole                 0.460365              -0.005738
# YearsSinceLastPromotion            0.404858              -0.002067
# YearsWithCurrManager               0.459188              -0.004096
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                             -0.021490        0.311309            0.212901
# MonthlyIncome                    0.030490        0.514168            0.363535
# DailyRate                       -0.037848       -0.034055            0.009932
# DistanceFromHome                -0.026556        0.009508            0.018845
# Education                        0.009819        0.069114            0.060236
# EnvironmentSatisfaction          0.027627        0.001458            0.018007
# HourlyRate                      -0.004607       -0.019582           -0.024106
# JobInvolvement                  -0.014617       -0.021355            0.008717
# JobLevel                         0.037818        0.534739            0.389447
# JobSatisfaction                 -0.019459       -0.003803           -0.002305
# MonthlyRate                      0.007864       -0.022886           -0.011868
# NumCompaniesWorked              -0.008366       -0.118421           -0.090754
# PercentSalaryHike               -0.002321       -0.035149           -0.000480
# PerformanceRating                0.004304        0.005013            0.036938
# RelationshipSatisfaction         0.019604        0.019367           -0.015123
# StockOptionLevel                 0.004129        0.015058            0.050818
# TotalWorkingYears                0.001008        0.628133            0.460365
# TrainingTimesLastYear            0.028072        0.003569           -0.005738
# WorkLifeBalance                  1.000000        0.012089            0.049856
# YearsAtCompany                   0.012089        1.000000            0.758754
# YearsInCurrentRole               0.049856        0.758754            1.000000
# YearsSinceLastPromotion          0.008941        0.618409            0.548056
# YearsWithCurrManager             0.002759        0.769212            0.714365
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.216513              0.202089
# MonthlyIncome                            0.344548              0.343788
# DailyRate                               -0.033229             -0.026363
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EnvironmentSatisfaction                  0.016194             -0.004999
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobSatisfaction                         -0.018214             -0.027656
# MonthlyRate                              0.001880             -0.035965
# NumCompaniesWorked                      -0.036814             -0.110319
# PercentSalaryHike                       -0.021565             -0.010966
# PerformanceRating                        0.019019              0.024731
# RelationshipSatisfaction                 0.033493             -0.000867
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404858              0.459188
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.618409              0.769212
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# * job level is strongly correlated with total working hours
#
# * Monthly income is strongly correlated with Job level
#
# * Monthly income is strongly correlated with total working hours
#
# * Age is strongly correlated with monthly income

# %% [markdown]
# **PRACTICE OPPORTUNITY #8:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.select_dtypes('number').corr(),cmap="crest");

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT OVERVIEW

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %%
df = pd.read_csv("kyphosis.csv")
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %% [markdown]
# ### INPUTS:
# **Age:** in months
#
# **Number:** the number of vertebrae involved
#
# **Start:** the number of the first (topmost) vertebra operated on
#
# ### OUTPUTS:
# **Kyphosis** which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
df.isnull().sum()
# Out:
# Kyphosis    0
# Age         0
# Number      0
# Start       0
# dtype: int64

# %%
df.describe().T
# Out:
#         count       mean        std  min   25%   50%    75%    max
# Age      81.0  83.654321  58.104251  1.0  26.0  87.0  130.0  206.0
# Number   81.0   4.049383   1.619423  2.0   3.0   4.0    5.0   10.0
# Start    81.0  11.493827   4.883962  1.0   9.0  13.0   16.0   18.0

# %%
df.Kyphosis.value_counts()
# Out:
# Kyphosis
# absent     64
# present    17
# Name: count, dtype: int64

# %%
ax = sns.barplot(x = df.Kyphosis.value_counts().index, y = df.Kyphosis.value_counts().values)
plt.title("Distribution of the Target Variable")
plt.xlabel("Kyphosis")
ax.bar_label(ax.containers[0])
plt.show()

# %%
df_con = ['Age', 'Number', 'Start']

# %%
for i in df_con:
    sns.histplot(data = df, x = i, fill = True, linewidth = 2, kde = True)
    plt.title(i)
    plt.show()

# %%
sns.pairplot(df, hue='Kyphosis');

# %%
print(f" maximum age: {df.Age.max()//12}\n minimum age: {df.Age.min()//12}\n average age: {df.Age.mean()//12}")
# Out:
#  maximum age: 17
#  minimum age: 0
#  average age: 6.0

# %%
age = df["Age"].agg(["min","max","mean"]) // 12
age
# Out:
# min      0.0
# max     17.0
# mean     6.0
# Name: Age, dtype: float64

# %%
df.Age.describe() // 12
# Out:
# count     6.0
# mean      6.0
# std       4.0
# min       0.0
# 25%       2.0
# 50%       7.0
# 75%      10.0
# max      17.0
# Name: Age, dtype: float64

# %%
# Let's draw the correlation matrix
df.select_dtypes('number').corr()
# Out:
#              Age    Number     Start
# Age     1.000000 -0.016687  0.057828
# Number -0.016687  1.000000 -0.425099
# Start   0.057828 -0.425099  1.000000

# %%
sns.heatmap(df.select_dtypes('number').corr(), annot=True, cmap='coolwarm');

# %%
# Let's convert the age column from data type int64 to float64
df['Age'] = df['Age'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     float64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.7+ KB

# %%
# Let's create a new column in years

df['Age in Years'] = df['Age'] // 12
df.head()
# Out:
#   Kyphosis    Age  Number  Start  Age in Years
# 0   absent   71.0       3      5           5.0
# 1   absent  158.0       3     14          13.0
# 2  present  128.0       4      5          10.0
# 3   absent    2.0       5      1           0.0
# 4   absent    1.0       4     15           0.0

# %%
df.describe().T
# Out:
#               count       mean        std  min   25%   50%    75%    max
# Age            81.0  83.654321  58.104251  1.0  26.0  87.0  130.0  206.0
# Number         81.0   4.049383   1.619423  2.0   3.0   4.0    5.0   10.0
# Start          81.0  11.493827   4.883962  1.0   9.0  13.0   16.0   18.0
# Age in Years   81.0   6.530864   4.809071  0.0   2.0   7.0   10.0   17.0

# %%
# Let's observe the minimum and maximum ages 

df[df.Age == df.Age.max()]
# Out:
#    Kyphosis    Age  Number  Start  Age in Years
# 73   absent  206.0       4     10          17.0

# %%
df[df.Age == df.Age.min()]
# Out:
#    Kyphosis  Age  Number  Start  Age in Years
# 4    absent  1.0       4     15           0.0
# 5    absent  1.0       2     16           0.0
# 13   absent  1.0       4     12           0.0
# 15   absent  1.0       3     16           0.0
# 36   absent  1.0       3      9           0.0

# %%
# Normalization
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalization = scaler.fit_transform(df['Age'].values.reshape(-1,1))
normalization[:10]
# Out:
# array([[0.34146341],
#        [0.76585366],
#        [0.6195122 ],
#        [0.00487805],
#        [0.        ],
#        [0.        ],
#        [0.29268293],
#        [0.17560976],
#        [0.54634146],
#        [0.28292683]])

# %%
# STANDARDIZATION
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled = scaler.fit_transform(df['Age'].values.reshape(-1,1))
scaled[:10]
# Out:
# array([[-0.21914343],
#        [ 1.28749437],
#        [ 0.7679641 ],
#        [-1.41406306],
#        [-1.43138074],
#        [-1.43138074],
#        [-0.39232019],
#        [-0.80794441],
#        [ 0.50819896],
#        [-0.42695554]])

# %% [markdown]
# # Great Job!
